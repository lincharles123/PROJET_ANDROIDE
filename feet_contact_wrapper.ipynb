# %%
import jax
import jax.numpy as jnp
from brax.v1 import envs

# %%
class feetContactWrapper(envs.env.Wrapper):
    def __init__(self, env: envs.Env):
        super().__init__(env)
        self.env = env

# %%
env = envs.create("ant")
random_key = jax.random.PRNGKey(0)
state = env.reset(random_key)

# %%
state.
# Out:
# State(qp=QP(pos=Array([[ 0.        ,  0.        ,  0.541039  ],
#        [ 0.3085345 ,  0.2906657 ,  0.541039  ],
#        [ 0.54284906,  0.4864034 ,  0.3105195 ],
#        [-0.29228583,  0.3071603 ,  0.541039  ],
#        [-0.49783003,  0.5458337 ,  0.31770772],
#        [-0.30153584, -0.29844022,  0.541039  ],
#        [-0.54672325, -0.5361524 ,  0.34112015],
#        [ 0.2970705 , -0.30284607,  0.541039  ],
#        [ 0.5210274 , -0.5401281 ,  0.32696694],
#        [ 0.        ,  0.        ,  0.        ]], dtype=float32), rot=Array([[ 1.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#        [ 9.9899971e-01, -9.9290997e-18,  0.0000000e+00, -4.4716690e-02],
#        [ 8.8777512e-01, -3.0942631e-01,  3.3842510e-01, -3.9738115e-02],
#        [ 9.9930739e-01, -8.2626980e-18,  0.0000000e+00, -3.7211884e-02],
#        [ 8.9760619e-01, -3.2214409e-01, -2.9901361e-01, -3.3424765e-02],
#        [ 9.9997008e-01, -1.7184489e-18,  0.0000000e+00, -7.7392058e-03],
# ...
