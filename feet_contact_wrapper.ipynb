# %%
from diversity_algorithms.environments.environments import create
import jax
import jax.numpy as jnp

# %%
env = create("ant-uni")

# %%
random_key = jax.random.PRNGKey(0)
state = env.reset(random_key)

# %%
env.step(state, jnp.zeros(env.action_size))
# Out:
# State(qp=QP(pos=Array([[-2.7563612e-04, -1.5058233e-04,  5.2868980e-01],
#        [ 3.0781296e-01,  2.9013431e-01,  5.3162104e-01],
#        [ 5.4242700e-01,  4.8598790e-01,  3.0926931e-01],
#        [-2.9265639e-01,  3.0698287e-01,  5.2840453e-01],
#        [-4.9866614e-01,  5.4610771e-01,  3.0529553e-01],
#        [-3.0157426e-01, -2.9871684e-01,  5.2776158e-01],
#        [-5.4643863e-01, -5.3673875e-01,  3.2763398e-01],
#        [ 2.9684490e-01, -3.0299005e-01,  5.2832633e-01],
#        [ 5.2101433e-01, -5.4063457e-01,  3.1434470e-01],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]], dtype=float32), rot=Array([[ 9.9999928e-01,  8.5595832e-04, -7.9545943e-04,  1.1855547e-04],
#        [ 9.9898922e-01,  1.4365830e-03, -1.1960029e-03, -4.4911668e-02],
#        [ 8.8946062e-01, -3.0702686e-01,  3.3615318e-01, -3.9943267e-02],
#        [ 9.9931842e-01,  3.9683876e-04, -4.2419144e-04, -3.6910649e-02],
#        [ 8.9819282e-01, -3.2096493e-01, -2.9853880e-01, -3.3253118e-02],
# ...
